# %% [markdown]
# # **32161314 김호준 현대예측론 중간과제**

# %% [markdown]
# **Python scikit-learn 선형회귀(Linear-Regression) 모델**을 이용한 전국 대학교 입학생 수 예측

# %% [markdown]
# # **Contents**
#
#
# ##**1. 서론**
#
# >1.1 연구 배경
#
# >1.2 연구 목적
#
# ##**2. 이론적 배경**
#
# >2.1 머신러닝
#
# >> 2.1.1 sk-learn 라이브러리를 이용한 회귀모델
#
# ##**3. 연구방법**
#
# > 3.1 연도별 대학교 입학자 수 회귀모델 생성
#
# > > 3.1.1 데이터 전처리
#
# >>> 1) 연도별 총입학 정원 데이터 추출
#
# > >> 2) 연도별 대학교 입학정원 데이터 추출
#
# >> >3) 연도별 고등학교 졸업인원 데이터 추출
#
# >> >4) 연도별 대학교 재학생 수 데이터 추출
#
# >> >5) 연도별 대학교 졸업생 수 데이터 추출
#
# > >>6) 연도별 전국 대학교 수 데이터 추출
#
# > >>7) 연도별 전국 대학교 학과 수 데이터 추출
#
# > >>8) 데이터 병합
#
# > >>9) 결측치 및 이상치 제거
#
# > >>10) 데이터 정규화
#
# > >>11) 데이터 표준화
#
# >> 3.1.2 회귀모델 설계
#
# ##**4. 조사결과**
#
# >4.1 대학교 입학자 수 회귀모델을 통한 예측
#
# >4.2 대학교 입학자 수 회귀분석 모델 평가
#
# >> 4.2.1 피처 유의성 검정
#
# >> 4.2.2 다중공선성
#
# >> 3.2.3 L2 규제 평가(릿지[Ridge])
#
# <br>
#
# ##**5. 결과 고찰 및 개선 방안**
#
# <br>
#
# ##**6. 결론**
#
# <br>
#
# ---
#
# **참고문헌**
#
# 1) 교육통계서비스: https://kess.kedi.re.kr/index
#
# >연도별 학교수
#
# >연도별 학과수
#
# >연도별 재적학생수
#
# >연도별 학년별 재적학생수
#
# >연도별 입학정원
#
# >연도별 입학자수
#
# >연도별 졸업자수
#
# 2) 파이썬 머신러닝 완벽 가이드(권철민)
#
# 3) 테디노트 깃허브 : https://github.com/teddylee777/machine-learning

# %% [markdown]
# 연도에 따른 대학교 입학자 수 회귀분석

# %% [markdown]
# 2.1.1 데이터 전처리

# %%
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1) 연도별 대학교 총입학 정원 데이터 추출

# %%
num_ad = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 입학자수.xlsx')

# %%
num_ad.head()
# Out:
#      연도  시도    입학자수  입학자수.1    전문대학  ...  대학원.1  대학원.2  대학원.3  대학원.4 대학원.5
# 0    연도  시도    입학자수    입학자수    전문대학  ...      계     석사     석사     박사    박사
# 1    연도  시도       계       여       계  ...      여      계      여      계     여
# 2  1999  전체  795998  356583  306802  ...  29183  73826  26647  10447  2536
# 3  2000  전체  819779  381957  318135  ...  35586  82374  32487  11705  3099
# 4  2001  전체  839516  393342  322687  ...  39484  86992  35937  12570  3547
#
# [5 rows x 32 columns]

# %%
num_ad1 = num_ad.copy()

# %%
nu = num_ad1.iloc[2:24 , [0,2]]

# %%
nu = nu.reset_index()

# %%
nu = nu.drop('index',axis=1)

# %%
nu = nu.astype('int')

# %%
nu  # 연도별 입학자수 (22,2) 데이터프레임 생성완료
# Out:
#       연도    입학자수
# 0   1999  795998
# 1   2000  819779
# 2   2001  839516
# 3   2002  819052
# 4   2003  776291
# 5   2004  773741
# 6   2005  769034
# 7   2006  775605
# 8   2007  786757
# 9   2008  786003
# 10  2009  791025
# 11  2010  817225
# 12  2011  832631
# 13  2012  817142
# 14  2013  788994
# 15  2014  791242
# 16  2015  774611
# 17  2016  756527
# 18  2017  735581
# 19  2018  734291
# 20  2019  733517
# 21  2020  726981

# %% [markdown]
# 2) 연도별 대학교 입학정원 데이터 추출

# %%
num_ag = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 입학정원.xlsx')

# %%
num_ag.head()
# Out:
#      연도  시도     학과수    전문대학  교육대학  ...  전공대학  기능대학     대학원   대학원.1  대학원.2
# 0    연도  시도     학과수    전문대학  교육대학  ...  전공대학  기능대학       계      석사     박사
# 1  1999  전체  807451  294250  4285  ...   NaN   NaN   99451   87485  11966
# 2  2000  전체  820666  294175  4735  ...   NaN   NaN  107391   94339  13052
# 3  2001  전체  827473  292035  4735  ...   NaN   NaN  113703   99524  14179
# 4  2002  전체  842866  293174  4855  ...   NaN   NaN  119083  103605  15478
#
# [5 rows x 17 columns]

# %%
ng = num_ag.loc[1:22,'학과수']

# %%
ng = ng.reset_index()

# %%
ng = ng.drop('index',axis = 1)

# %%
ng #입학정원 데이터 추출 완료
# Out:
#        학과수
# 0   807451
# 1   820666
# 2   827473
# 3   842866
# 4   843693
# 5   856976
# 6   838582
# 7   800920
# 8   787035
# 9   788806
# 10  791972
# 11  786587
# 12  801064
# 13  793135
# 14  772776
# 15  776553
# 16  758111
# 17  743201
# 18  732125
# 19  721678
# 20  717992
# 21  713690

# %%
df = pd.concat([nu,ng], axis = 1)

# %%
df = df.rename(columns={'학과수':'입학정원'})

# %%
df # 초기병합 완료
# Out:
#       연도    입학자수    입학정원
# 0   1999  795998  807451
# 1   2000  819779  820666
# 2   2001  839516  827473
# 3   2002  819052  842866
# 4   2003  776291  843693
# 5   2004  773741  856976
# 6   2005  769034  838582
# 7   2006  775605  800920
# 8   2007  786757  787035
# 9   2008  786003  788806
# 10  2009  791025  791972
# 11  2010  817225  786587
# 12  2011  832631  801064
# 13  2012  817142  793135
# 14  2013  788994  772776
# 15  2014  791242  776553
# 16  2015  774611  758111
# 17  2016  756527  743201
# 18  2017  735581  732125
# 19  2018  734291  721678
# 20  2019  733517  717992
# 21  2020  726981  713690

# %% [markdown]
# 3) 연도별 고등학교 졸업인원 데이터 추출

# %%
num_hg = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 초중고 졸업자.xlsx')

# %%
num_hg.head()
# Out:
#      연도  시도        계      계.1     유치원  ... 고등공민.1  고등기술학교 고등기술학교.1  각종학교 각종학교.1
# 0    연도  시도        계        계     유치원  ...   고등공민  고등기술학교   고등기술학교  각종학교   각종학교
# 1    연도  시도       전체       여자      전체  ...     여자      전체       여자    전체     여자
# 2  1999  전국  2493983  1195841  398807  ...    138    3731     2361  2269   1436
# 3  2000  전국  2418103  1154090  392441  ...    103    4034     2088  3447   1581
# 4  2001  전국  2391416  1140149  399506  ...     48    3092     1626  4009   1670
#
# [5 rows x 34 columns]

# %%
nh = num_hg.loc[2:23,'고등학교']

# %%
nh = nh.reset_index(drop=True)

# %%
nh
# Out:
# 0     747723
# 1     764712
# 2     735739
# 3     670713
# 4     590413
# 5     588550
# 6     569272
# 7     568055
# 8     571357
# 9     581921
# 10    576298
# 11    633539
# 12    648468
# 13    636724
# 14    631197
# 15    632983
# 16    615462
# 17    607598
# 18    583608
# 19    566545
# 20    568736
# 21    500373
# Name: 고등학교, dtype: object

# %% [markdown]
# 4) 연도별 대학교 재학생 수 데이터 추출

# %%
num_in = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 재적학생수.xlsx')

# %%
num_in.head()
# Out:
#      연도  시도    재적학생수  재적학생수.1    전문대학  ...  대학원.1   대학원.2  대학원.3  대학원.4 대학원.5
# 0    연도  시도    재적학생수    재적학생수    전문대학  ...      계      석사     석사     박사    박사
# 1    연도  시도        계        여       계  ...      여       계      여      계     여
# 2  1999  전체  3154245  1189103  859547  ...  66529  175849  59635  28924  6894
# 3  2000  전체  3363549  1286762  913273  ...  80072  197436  72177  32001  7895
# 4  2001  전체  3500560  1350523  952649  ...  91677  209865  82936  33405  8741
#
# [5 rows x 32 columns]

# %%
ni = num_in.loc[2:23,'재적학생수']

# %%
ni
# Out:
# 2     3154245
# 3     3363549
# 4     3500560
# 5     3577447
# 6     3531721
# 7     3555115
# 8     3548728
# 9     3545774
# 10    3558711
# 11    3562844
# 12    3591088
# 13    3644158
# 14    3735706
# 15    3728802
# 16    3709734
# 17    3668747
# 18    3608071
# 19    3516607
# 20    3437309
# 21    3378393
# 22    3326733
# 23    3276327
# Name: 재적학생수, dtype: object

# %%
ni = ni.reset_index(drop=True)

# %% [markdown]
# 5) 연도별 대학교 졸업생 수 데이터 추출

# %%
num_ed = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 졸업자수.xlsx')

# %%
num_ed.head()
# Out:
#      연도  시도    졸업자수  졸업자수.1    전문대학  ...  대학원.1  대학원.2  대학원.3 대학원.4 대학원.5
# 0    연도  시도    졸업자수    졸업자수    전문대학  ...      계     석사     석사    박사    박사
# 1    연도  시도       계       여       계  ...      여      계      여     계     여
# 2  1999  전체  511984  247932  212726  ...  13961  41482  12817  5586  1144
# 3  2000  전체  542184  267951  223489  ...  16229  47226  14971  6141  1258
# 4  2001  전체  584340  289084  232972  ...  19514  53109  18034  6221  1480
#
# [5 rows x 32 columns]

# %%
ne = num_ed.loc[2:23,'졸업자수']

# %%
ne
# Out:
# 2     511984
# 3     542184
# 4     584340
# 5     603281
# 6     633730
# 7     627270
# 8     634523
# 9     638259
# 10    642987
# 11    681758
# 12    636628
# 13    628689
# 14    653118
# 15    665057
# 16    657013
# 17    667056
# 18    680698
# 19    685089
# 20    678845
# 21    660772
# 22    653388
# 23    666083
# Name: 졸업자수, dtype: object

# %%
ne = ne.reset_index(drop=True)

# %% [markdown]
# 6) 연도별 전국 대학교 수 데이터 추출

# %%
num_co = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 학교수.xlsx')

# %%
num_co.head()
# Out:
#      연도  시도  학교수  전문대학  교육대학  일반대학  ...  원격및사이버대학  사내대학  전공대학  기능대학    대학원  대학원.1
# 0    연도  시도  학교수  전문대학  교육대학  일반대학  ...  원격및사이버대학  사내대학  전공대학  기능대학  대학원대학  부설대학원
# 1  1999  전체  368   161    11   158  ...       NaN   NaN   NaN   NaN     14  (662)
# 2  2000  전체  372   158    11   161  ...       NaN   NaN   NaN   NaN     17  (812)
# 3  2001  전체  374   158    11   162  ...       NaN   NaN   NaN   NaN     18  (887)
# 4  2002  전체  376   159    11   163  ...       NaN   NaN   NaN   NaN     18  (927)
#
# [5 rows x 16 columns]

# %%
nc = num_co.loc[1:22,'학교수']

# %%
nc
# Out:
# 1     368
# 2     372
# 3     374
# 4     376
# 5     388
# 6     411
# 7     419
# 8     412
# 9     408
# 10    405
# 11    407
# 12    411
# 13    431
# 14    429
# 15    430
# 16    430
# 17    431
# 18    430
# 19    430
# 20    430
# 21    430
# 22    429
# Name: 학교수, dtype: object

# %%
nc = nc.reset_index(drop=True)

# %% [markdown]
# 7) 연도별 전국 대학교 학과 수 데이터 추출

# %%
num_mj = pd.read_excel('/content/drive/MyDrive/현대예측론 중간과제/2020_연도별 학과수.xlsx')

# %%
num_mj.head()
# Out:
#      연도  시도    학과수  전문대학  교육대학  일반대학  ...  사내대학  전공대학  기능대학    대학원 대학원.1 대학원.2
# 0    연도  시도    학과수  전문대학  교육대학  일반대학  ...  사내대학  전공대학  기능대학      계    석사    박사
# 1  1999  전체  22579  4464    14  8854  ...   NaN   NaN   NaN   8230  6236  1994
# 2  2000  전체  25083  4835    14  9377  ...   NaN   NaN   NaN   9742  7330  2412
# 3  2001  전체  26584  5110    13  9723  ...   NaN   NaN   NaN  10547  7880  2667
# 4  2002  전체  27256  5200    12  9659  ...   NaN   NaN   NaN  11230  8283  2947
#
# [5 rows x 17 columns]

# %%
nm = num_mj.loc[1:22,'학과수']

# %%
nm
# Out:
# 1     22579
# 2     25083
# 3     26584
# 4     27256
# 5     27834
# 6     29175
# 7     30397
# 8     32177
# 9     32697
# 10    32798
# 11    33012
# 12    33415
# 13    33809
# 14    34496
# 15    34522
# 16    34084
# 17    34764
# 18    34290
# 19    34740
# 20    34070
# 21    33988
# 22    34054
# Name: 학과수, dtype: object

# %%
nm = nm.reset_index(drop=True)

# %% [markdown]
# 8) 데이터 병합

# %%
df = pd.concat([df,nh], axis = 1)

# %%
df = pd.concat([df,ni], axis = 1)

# %%
df = pd.concat([df,ne], axis = 1)

# %%
df = pd.concat([df,nc], axis = 1)

# %%
df = pd.concat([df,nm], axis = 1)

# %%
df # 병합완료
# Out:
#       연도    입학자수    입학정원    고등학교    재적학생수    졸업자수  학교수    학과수
# 0   1999  795998  807451  747723  3154245  511984  368  22579
# 1   2000  819779  820666  764712  3363549  542184  372  25083
# 2   2001  839516  827473  735739  3500560  584340  374  26584
# 3   2002  819052  842866  670713  3577447  603281  376  27256
# 4   2003  776291  843693  590413  3531721  633730  388  27834
# 5   2004  773741  856976  588550  3555115  627270  411  29175
# 6   2005  769034  838582  569272  3548728  634523  419  30397
# 7   2006  775605  800920  568055  3545774  638259  412  32177
# 8   2007  786757  787035  571357  3558711  642987  408  32697
# 9   2008  786003  788806  581921  3562844  681758  405  32798
# 10  2009  791025  791972  576298  3591088  636628  407  33012
# 11  2010  817225  786587  633539  3644158  628689  411  33415
# 12  2011  832631  801064  648468  3735706  653118  431  33809
# 13  2012  817142  793135  636724  3728802  665057  429  34496
# 14  2013  788994  772776  631197  3709734  657013  430  34522
# 15  2014  791242  776553  632983  3668747  667056  430  34084
# 16  2015  774611  758111  615462  3608071  680698  431  34764
# 17  2016  756527  743201  607598  3516607  685089  430  34290
# 18  2017  735581  732125  583608  3437309  678845  430  34740
# 19  2018  734291  721678  566545  3378393  660772  430  34070
# 20  2019  733517  717992  568736  3326733  653388  430  33988
# 21  2020  726981  713690  500373  3276327  666083  429  34054

# %% [markdown]
# 9) 결측치 및 이상치 제거

# %%
df.info() #확인 결과 결측치 없음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      22 non-null     int64
#  1   입학자수    22 non-null     int64
#  2   입학정원    22 non-null     object
#  3   고등학교    22 non-null     object
#  4   재적학생수   22 non-null     object
#  5   졸업자수    22 non-null     object
#  6   학교수     22 non-null     object
#  7   학과수     22 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.5+ KB

# %%
df = df.astype('int') # 데이터 프레임 정수형으로 변환

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      22 non-null     int64
#  1   입학자수    22 non-null     int64
#  2   입학정원    22 non-null     int64
#  3   고등학교    22 non-null     int64
#  4   재적학생수   22 non-null     int64
#  5   졸업자수    22 non-null     int64
#  6   학교수     22 non-null     int64
#  7   학과수     22 non-null     int64
# dtypes: int64(8)
# memory usage: 1.5 KB

# %% [markdown]
# 10) 데이터 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler = MinMaxScaler()

# %%
df = min_max_scaler.fit_transform(df)

# %%
pd.DataFrame(df, columns=['연도',	'입학자수',	'입학정원',	'고등학교졸업자수',	'재적학생수','졸업자수','학교수','학과수'])
# Out:
#           연도      입학자수      입학정원  ...      졸업자수       학교수       학과수
# 0   0.000000  0.613294  0.654363  ...  0.000000  0.000000  0.000000
# 1   0.047619  0.824615  0.746591  ...  0.174461  0.063492  0.205499
# 2   0.095238  1.000000  0.794097  ...  0.417989  0.095238  0.328683
# 3   0.142857  0.818154  0.901526  ...  0.527408  0.126984  0.383833
# 4   0.190476  0.438175  0.907297  ...  0.703307  0.317460  0.431268
# 5   0.238095  0.415515  1.000000  ...  0.665989  0.682540  0.541321
# 6   0.285714  0.373688  0.871627  ...  0.707888  0.809524  0.641609
# 7   0.333333  0.432079  0.608782  ...  0.729471  0.698413  0.787690
# 8   0.380952  0.531177  0.511878  ...  0.756783  0.634921  0.830365
# 9   0.428571  0.524477  0.524238  ...  0.980757  0.587302  0.838654
# 10  0.476190  0.569103  0.546334  ...  0.720049  0.619048  0.856217
# 11  0.523810  0.801919  0.508752  ...  0.674186  0.682540  0.889290
# 12  0.571429  0.938819  0.609787  ...  0.815309  1.000000  0.921625
# 13  0.619048  0.801182  0.554451  ...  0.884278  0.968254  0.978006
# 14  0.666667  0.551055  0.412364  ...  0.837809  0.984127  0.980140
# 15  0.714286  0.571031  0.438724  ...  0.895826  0.984127  0.944194
# 16  0.761905  0.423246  0.310016  ...  0.974634  1.000000  1.000000
# 17  0.809524  0.262549  0.205959  ...  1.000000  0.984127  0.961100
# 18  0.857143  0.076421  0.128659  ...  0.963929  0.984127  0.998030
# 19  0.904762  0.064958  0.055749  ...  0.859525  0.984127  0.943045
# 20  0.952381  0.058080  0.030024  ...  0.816868  0.984127  0.936315
# 21  1.000000  0.000000  0.000000  ...  0.890205  0.968254  0.941732
#
# [22 rows x 8 columns]

# %% [markdown]
# 11) 데이터 표준화

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()

# %%
df = standard_scaler.fit_transform(df)

# %%
df = pd.DataFrame(df, columns=['연도',	'입학자수',	'입학정원',	'고등학교졸업자수',	'재적학생수','졸업자수','학교수','학과수'])

# %%
df
# Out:
#           연도      입학자수      입학정원  ...      졸업자수       학교수       학과수
# 0  -1.655032  0.385587  0.481757  ... -2.925015 -2.013115 -2.580559
# 1  -1.497410  1.131603  0.799667  ... -2.223207 -1.827614 -1.866507
# 2  -1.339788  1.750758  0.963421  ... -1.243557 -1.734863 -1.438475
# 3  -1.182166  1.108797  1.333725  ... -0.803393 -1.642112 -1.246844
# 4  -1.024544 -0.232626  1.353620  ... -0.095798 -1.085607 -1.082019
# 5  -0.866921 -0.312620  1.673165  ... -0.245920 -0.018972 -0.699613
# 6  -0.709299 -0.460280  1.230666  ... -0.077370  0.352032 -0.351141
# 7  -0.551677 -0.254146  0.324643  ...  0.009450  0.027404  0.156452
# 8  -0.394055  0.095695 -0.009384  ...  0.119322 -0.158098  0.304737
# 9  -0.236433  0.072042  0.033220  ...  1.020309 -0.297224  0.333539
# 10 -0.078811  0.229583  0.109384  ... -0.028453 -0.204474  0.394564
# 11  0.078811  1.051484 -0.020162  ... -0.212945 -0.018972  0.509486
# 12  0.236433  1.534774  0.328107  ...  0.354753  0.908537  0.621841
# 13  0.394055  1.048880  0.137362  ...  0.632200  0.815786  0.817749
# 14  0.551677  0.165870 -0.352409  ...  0.445268  0.862161  0.825163
# 15  0.709299  0.236391 -0.261547  ...  0.678654  0.862161  0.700261
# 16  0.866921 -0.285328 -0.705200  ...  0.995676  0.908537  0.894173
# 17  1.024544 -0.852628 -1.063886  ...  1.097717  0.862161  0.759005
# 18  1.182166 -1.509709 -1.330338  ...  0.952615  0.862161  0.887329
# 19  1.339788 -1.550177 -1.581658  ...  0.532622  0.862161  0.696269
# 20  1.497410 -1.574457 -1.670331  ...  0.361028  0.862161  0.672885
# 21  1.655032 -1.779493 -1.773823  ...  0.656043  0.815786  0.691706
#
# [22 rows x 8 columns]

# %% [markdown]
# 2.1.2 회귀모델 설계

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('입학자수', 1), df['입학자수'])

# %%
x_train.shape, x_test.shape
# Out:
# ((16, 7), (6, 7))

# %%
x_train.head()
# Out:
#           연도      입학정원  고등학교졸업자수     재적학생수      졸업자수       학교수       학과수
# 7  -0.551677  0.324643 -0.781688  0.151677  0.009450  0.027404  0.156452
# 3  -1.182166  1.333725  0.833852  0.368849 -0.803393 -1.642112 -1.246844
# 9  -0.236433  0.033220 -0.563477  0.268721  1.020309 -0.297224  0.333539
# 21  1.655032 -1.773823 -1.846807 -1.695845  0.656043  0.815786  0.691706
# 6  -0.709299  1.230666 -0.762536  0.171931 -0.077370  0.352032 -0.351141

# %%
y_train.head()
# Out:
# 7    -0.254146
# 3     1.108797
# 9     0.072042
# 21   -1.779493
# 6    -0.460280
# Name: 입학자수, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
import matplotlib.pyplot as plt  # 테디 깃허브 출처 메소드
import seaborn as sns

my_predictions = {}

colors = ['r', 'c', 'm', 'y', 'k', 'khaki', 'teal', 'orchid', 'sandybrown',
          'greenyellow', 'dodgerblue', 'deepskyblue', 'rosybrown', 'firebrick',
          'deeppink', 'crimson', 'salmon', 'darkred', 'olivedrab', 'olive', 
          'forestgreen', 'royalblue', 'indigo', 'navy', 'mediumpurple', 'chocolate',
          'gold', 'darkorange', 'seagreen', 'turquoise', 'steelblue', 'slategray', 
          'peru', 'midnightblue', 'slateblue', 'dimgray', 'cadetblue', 'tomato'
         ]

def plot_predictions(name_, pred, actual):
    df = pd.DataFrame({'prediction': pred, 'actual': y_test})
    df = df.sort_values(by='actual').reset_index(drop=True)

    plt.figure(figsize=(12, 9))
    plt.scatter(df.index, df['prediction'], marker='x', color='r')
    plt.scatter(df.index, df['actual'], alpha=0.7, marker='o', color='black')
    plt.title(name_, fontsize=15)
    plt.legend(['prediction', 'actual'], fontsize=12)
    plt.show()

def mse_eval(name_, pred, actual):
    global predictions
    global colors

    plot_predictions(name_, pred, actual)

    mse = mean_squared_error(pred, actual)
    my_predictions[name_] = mse

    y_value = sorted(my_predictions.items(), key=lambda x: x[1], reverse=True)
    
    df = pd.DataFrame(y_value, columns=['model', 'mse'])
    print(df)
    min_ = df['mse'].min() - 10
    max_ = df['mse'].max() + 10
    
    length = len(df)
    
    plt.figure(figsize=(10, length))
    ax = plt.subplot()
    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df['model'], fontsize=15)
    bars = ax.barh(np.arange(len(df)), df['mse'])
    
    for i, v in enumerate(df['mse']):
        idx = np.random.choice(len(colors))
        bars[i].set_color(colors[idx])
        ax.text(v + 2, i, str(round(v, 3)), color='k', fontsize=15, fontweight='bold')
        
    plt.title('MSE Error', fontsize=18)
    plt.xlim(min_, max_)
    
    plt.show()

def remove_model(name_):
    global my_predictions
    try:
        del my_predictions[name_]
    except KeyError:
        return False
    return True

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(n_jobs=-1)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
x_test
# Out:
#           연도      입학정원  고등학교졸업자수     재적학생수      졸업자수       학교수       학과수
# 16  0.866921 -0.705200 -0.035639  0.578829  0.995676  0.908537  0.894173
# 4  -1.024544  1.353620 -0.429838  0.055319 -0.095798 -1.085607 -1.082019
# 19  1.339788 -1.581658 -0.805451 -0.996008  0.532622  0.862161  0.696269
# 14  0.551677 -0.352409  0.211985  1.275904  0.445268  0.862161  0.825163
# 20  1.497410 -1.670331 -0.770971 -1.350226  0.361028  0.862161  0.672885
# 0  -1.655032  0.481757  2.045767 -2.532927 -2.925015 -2.013115 -2.580559

# %% [markdown]
# 3.1 대학교 입학자 수 회귀모델을 통한 예측

# %%
pred = model.predict(df.drop('입학자수', 1))

# %%
pred[:22]
# Out:
# array([ 0.21055477,  1.18913416,  1.43601575,  1.3492671 ,  0.10233702,
#        -0.21242412, -0.44576754, -0.12835411,  0.10052904, -0.26051597,
#         0.42415625,  1.09436825,  1.03340046,  0.88166318,  0.97598122,
#         0.55134117, -0.0067232 , -0.59708539, -1.10436031, -1.26218675,
#        -1.49843405, -2.2202373 ])

# %% [markdown]
# 3.2 대학교 입학자 수 회귀분석 모델 평가

# %% [markdown]
# 3.2.1 피쳐 유의성 검정

# %%
import statsmodels.api as sm

x_train = sm.add_constant(x_train)
model = sm.OLS(y_train, x_train).fit()
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   입학자수   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     14.37
# Date:                Sun, 31 Oct 2021   Prob (F-statistic):           0.000594
# Time:                        05:16:15   Log-Likelihood:                -1.1977
# No. Observations:                  16   AIC:                             18.40
# Df Residuals:                       8   BIC:                             24.58
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0585      0.095      0.616      0.555      -0.160       0.277
# 연도             0.1563      0.555      0.282      0.785      -1.123       1.435
# 입학정원           0.8098      0.807      1.004      0.345      -1.051       2.670
# 고등학교졸업자수       0.7625      0.345      2.212      0.058      -0.033       1.558
# 재적학생수         -0.0400      0.601     -0.067      0.949      -1.427       1.346
# 졸업자수          -0.4050      0.277     -1.463      0.182      -1.043       0.233
# 학교수           -0.7671      0.382     -2.007      0.080      -1.649       0.114
# 학과수            1.6129      1.033      1.562      0.157      -0.769       3.994
# ==============================================================================
# Omnibus:                        8.648   Durbin-Watson:                   2.533
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                5.367
# Skew:                           1.304   Prob(JB):                       0.0683
# Kurtosis:                       4.118   Cond. No.                         34.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# *3.2*.2 다중공선성

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif["features"] = x_train.columns
vif.round(1)
# Out:
#    VIF Factor  features
# 0         1.1     const
# 1        34.9        연도
# 2        79.8      입학정원
# 3        13.0  고등학교졸업자수
# 4        43.7     재적학생수
# 5         8.4      졸업자수
# 6        16.8       학교수
# 7       125.0       학과수

# %% [markdown]
# 3.2.3 L2 규제 평가(릿지[Ridge])

# %%
mse_eval('LinearRegression', pred, y_test)
# Out:
#               model       mse
# 0  LinearRegression  0.125227

# %%
from sklearn.linear_model import Ridge

# %%
alphas = [100, 10, 1, 0.1, 0.01, 0.001, 0.0001]

# %%
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    ridge.fit(x_train, y_train)
    pred = ridge.predict(x_test)
    mse_eval('Ridge(alpha={})'.format(alpha), pred, y_test)
# Out:
#               model       mse
# 0  Ridge(alpha=100)  0.754813
# 1  LinearRegression  0.125227
#               model       mse
# 0  Ridge(alpha=100)  0.754813
# 1   Ridge(alpha=10)  0.234411
# 2  LinearRegression  0.125227
#               model       mse
# 0  Ridge(alpha=100)  0.754813
# 1   Ridge(alpha=10)  0.234411
# 2  LinearRegression  0.125227
# 3    Ridge(alpha=1)  0.109837
#               model       mse
# 0  Ridge(alpha=100)  0.754813
# 1   Ridge(alpha=10)  0.234411
# 2  LinearRegression  0.125227
# 3    Ridge(alpha=1)  0.109837
# 4  Ridge(alpha=0.1)  0.103030
#                model       mse
# 0   Ridge(alpha=100)  0.754813
# 1    Ridge(alpha=10)  0.234411
# 2   LinearRegression  0.125227
# 3  Ridge(alpha=0.01)  0.118856
# 4     Ridge(alpha=1)  0.109837
# 5   Ridge(alpha=0.1)  0.103030
#                 model       mse
# 0    Ridge(alpha=100)  0.754813
# 1     Ridge(alpha=10)  0.234411
# 2    LinearRegression  0.125227
# 3  Ridge(alpha=0.001)  0.124462
# 4   Ridge(alpha=0.01)  0.118856
# 5      Ridge(alpha=1)  0.109837
# 6    Ridge(alpha=0.1)  0.103030
#                  model       mse
# 0     Ridge(alpha=100)  0.754813
# 1      Ridge(alpha=10)  0.234411
# 2     LinearRegression  0.125227
# 3  Ridge(alpha=0.0001)  0.125149
# 4   Ridge(alpha=0.001)  0.124462
# 5    Ridge(alpha=0.01)  0.118856
# 6       Ridge(alpha=1)  0.109837
# 7     Ridge(alpha=0.1)  0.103030
